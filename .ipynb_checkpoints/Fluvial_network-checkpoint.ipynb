# %%
import numpy as np
from matplotlib import pyplot as plt

from landlab import RasterModelGrid, imshow_grid
from landlab.components import (
    ChannelProfiler,
    ChiFinder,
    FlowAccumulator,
    SteepnessFinder,
    StreamPowerEroder,
    LinearDiffuser,
)
from landlab.io import write_esri_ascii
from landlab.io import read_esri_ascii

# %%
(mg, z) = read_esri_ascii("sg_raster_sample.asc", name="topographic__elevation")

# %%
# %matplotlib inline
imshow_grid(mg, "topographic__elevation")
# Out:
# /home/tarangui/.conda/envs/Salar_env/lib/python3.7/site-packages/landlab/plot/imshow.py:267: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("pink"))
#   cmap.set_bad(color=color_for_closed)
# /home/tarangui/.conda/envs/Salar_env/lib/python3.7/site-packages/landlab/plot/imshow.py:307: MatplotlibDeprecationWarning: The 'norm' parameter to Colorbar has no effect because it is overridden by the mappable; it is deprecated since 3.3 and will be removed two minor releases later.
#   cb = plt.colorbar(norm=norm, shrink=shrink)

# %%
min_z = np.min(z[np.where(z > 0)])
max_z = np.max(z[np.where(z > 0)])
#help(imshow_grid)
imshow_grid(mg, 'topographic__elevation', limits=(min_z, max_z))

# %%
mg.status_at_node[np.isclose(z, -9999.)] = mg.BC_NODE_IS_CLOSED
mg.set_watershed_boundary_condition('topographic__elevation', -9999., True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-62b81f374f94> in <module>
#       1 mg.status_at_node[np.isclose(z, -9999.)] = mg.BC_NODE_IS_CLOSED
# ----> 2 mg.set_watershed_boundary_condition('topographic__elevation', -9999., True)
#
# ~/.conda/envs/Salar_env/lib/python3.7/site-packages/landlab/grid/raster.py in set_watershed_boundary_condition(self, node_data, nodata_value, return_outlet_id, remove_disconnected, adjacency_method)
#    2000                             "They have the following node IDs: \n"
#    2001                             + str(potential_locs)
# -> 2002                             + "\nUse the method set_watershed_boundary_condition_outlet_id "
#    2003                             "to explicitly select one of these "
#    2004                             "IDs as the outlet node."
#
# ValueError: Grid has two potential outlet nodes.They have the following node IDs:
# [660038 660940]
# Use the method set_watershed_boundary_condition_outlet_id to explicitly select one of these IDs as the outlet node.

# %%
mg.status_at_node[660038]= mg.BC_NODE_IS_FIXED_VALUE #THIS SHOULD MAKE THIS RUN FASTER

# %%
fr = FlowAccumulator(mg, flow_director='D8',depression_finder='DepressionFinderAndRouter')
fr.run_one_step()
    
# Plot channel profiles
profiler = ChannelProfiler(mg,minimum_channel_threshold  = 1, main_channel_only =False,number_of_watersheds =None)
profiler.run_one_step()
            
plt.figure()
imshow_grid(mg,"topographic__elevation")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c1336d4d7a5f> in <module>
#       1 fr = FlowAccumulator(mg, flow_director='D8',depression_finder='DepressionFinderAndRouter')
# ----> 2 fr.run_one_step()
#       3
#       4 # Plot channel profiles
#       5 profiler = ChannelProfiler(mg,minimum_channel_threshold  = 1, main_channel_only =False,number_of_watersheds =None)
#
# ~/.conda/envs/Salar_env/lib/python3.7/site-packages/landlab/components/flow_accum/flow_accumulator.py in run_one_step(self)
#    1245         the flow director or the depression finder.
#    1246         """
# -> 1247         self.accumulate_flow()
#    1248
#    1249
#
# ~/.conda/envs/Salar_env/lib/python3.7/site-packages/landlab/components/flow_accum/flow_accumulator.py in accumulate_flow(self, update_flow_director, update_depression_finder)
#    1162                     # are pits, or there were flooded nodes from last timestep.
#    1163                     if self.pits_present or self.flooded_nodes_present:
# -> 1164                         self._depression_finder.update()
#    1165
#    1166                     # if FlowDirectorSteepest is used, update the link directions
#
# ~/.conda/envs/Salar_env/lib/python3.7/site-packages/landlab/components/depression_finder/lake_mapper.py in update(self)
#     839     def update(self):
#     840         """Alias for map_depressions."""
# --> 841         self.map_depressions()
#     842
#     843     def map_depressions(self):
#
# ~/.conda/envs/Salar_env/lib/python3.7/site-packages/landlab/components/depression_finder/lake_mapper.py in map_depressions(self)
#     917         self._flood_status[self._pit_node_ids] = _PIT
#     918
# --> 919         self._identify_depressions_and_outlets(self._reroute_flow)
#     920
#     921         if self._reroute_flow and ("flow__receiver_node" in self._grid.at_node):
#
# ~/.conda/envs/Salar_env/lib/python3.7/site-packages/landlab/components/depression_finder/lake_mapper.py in _identify_depressions_and_outlets(self, reroute_flow)
#     828                 self._depression_outlets.append(self._grid.BAD_INDEX)
#     829             else:
# --> 830                 self.find_depression_from_pit(pit_node, reroute_flow)
#     831                 self._pits_flooded += 1
#     832
#
# ~/.conda/envs/Salar_env/lib/python3.7/site-packages/landlab/components/depression_finder/lake_mapper.py in find_depression_from_pit(self, pit_node, reroute_flow)
#     769                 nodes_this_depression,
#     770                 pit_count,
# --> 771                 self._BIG_ELEV,
#     772             )
#     773             # note this can return the supplied node, if - somehow - the
#
# KeyboardInterrupt:

# %%
ChannelProfiler?
fa = FlowAccumulator(mg, 'topographic__elevation', flow_director='FlowDirectorSteepest')
profiler = ChannelProfiler(mg, minimum_channel_threshold  = 1e5, main_channel_only =False,number_of_watersheds =None)

plt.figure()
imshow_grid(mg,"topographic__elevation")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d585d5389260> in <module>
#       1 get_ipython().run_line_magic('pinfo', 'ChannelProfiler')
#       2 fa = FlowAccumulator(mg, 'topographic__elevation', flow_director='FlowDirectorSteepest')
# ----> 3 profiler = ChannelProfiler(mg, main_channel_only =False,number_of_watersheds =None)
#       4
#       5 plt.figure()
#
# ~/.conda/envs/Salar_env/lib/python3.7/site-packages/landlab/components/profiler/channel_profiler.py in __init__(self, grid, channel_definition_field, number_of_watersheds, minimum_outlet_threshold, main_channel_only, outlet_nodes, minimum_channel_threshold, cmap)
#     608                 " area. {vals}".format(vals=starting_da)
#     609             )
# --> 610             raise ValueError(msg)
#     611
#     612         self._outlet_nodes = outlet_nodes
#
# ValueError: The number of watersheds requested by the ChannelProfiler is greater than the number in the domain with channel_definition_field area. []
